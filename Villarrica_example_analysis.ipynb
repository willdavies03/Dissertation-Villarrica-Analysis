# %%
import yaml
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import cartopy.crs as ccrs
import cmcrameri.cm as ccm
from shapely.geometry import Polygon
from cartopy.geodesic import Geodesic
import cartopy.feature as cfeature

# %%
# Set region name
name = 'Villarrica'
start_date = '2018-06-01'
end_date = '2026-03-01'

# Read in the region details
with open('regions.yml', 'r') as ymlfile:
    config = yaml.load(ymlfile, Loader=yaml.FullLoader)[name]

# %%
vlat, vlon = config['vent_location']

fig, ax = plt.subplots(
    subplot_kw={
        'projection': ccrs.Orthographic(vlon, vlat),
        'extent': config['bounds']
    }
)
srcrs = ccrs.PlateCarree()

ax.coastlines()
gl = ax.gridlines(ls='--', draw_labels=True)
gl.right_labels = False

circles = Polygon(Geodesic().circle(
    vlon, vlat, config['radius'], n_samples=360
))
ax.add_feature(cfeature.ShapelyFeature(
    [circles], srcrs, fc='None', ec="C1", lw=2,
    linestyle="-", zorder=10, alpha=0.5
))

for i, (clat, clon) in enumerate(config['clear_locations']):

    circles = Polygon(Geodesic().circle(
        clon, clat, config['radius'], n_samples=360
    ))
    ax.add_feature(cfeature.ShapelyFeature(
        [circles], srcrs, fc='None', ec="C2", lw=4,
        linestyle="-", zorder=10, alpha=0.5
    ))
    ax.text(
        clon, clat, f'C{i+1}', color='C2', ha='center', va='center',
        transform=srcrs
    )

fname = f"{name}_{start_date}_{end_date}_so2_data.nc"

# Open the file
with xr.open_dataset(fname) as ds:

    so2 = ds.SO2.sum(axis=0)
    so2 = so2 / np.abs(np.max(so2))

    m = ax.pcolormesh(
        ds.x, ds.y, so2, transform=srcrs, cmap=ccm.vik, vmin=-1, vmax=1
    )
    plt.colorbar(m, ax=ax, label='Relative SO$_2$ Signal (a.u.)')

#plt.savefig("figure.png", dpi=800, bbox_inches='tight')
plt.show()

# %%
# Read in time series data
df = pd.read_csv(f'{name}_{start_date}_{end_date}_SO2_time_seriesnanmean.csv', parse_dates=['date'])

# Replace all zeros with NaN values
df.replace(0, np.nan, inplace=True)

# Fill in with interpolated values
df.interpolate(inplace=True)

# %%
# Plot the raw data
fig, ax = plt.subplots(figsize=[7, 4])

ax.plot(df['date'], np.cumsum(df['volcano']), label='Volcano', color='k', lw=2)
for i in range(len(config['clear_locations'])):
    ax.plot(df['date'], np.cumsum(df[f'clear_{i+1}']), f'C{i}-', alpha=0.5, label=f'Clear {i+1}')

ax.legend()

locator = mdates.AutoDateLocator()
formatter = mdates.ConciseDateFormatter(locator)
ax.xaxis.set_major_locator(locator)
ax.xaxis.set_major_formatter(formatter)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# -------------------------------------------
# SET UP FIGURE
# -------------------------------------------
fig, axes = plt.subplots(
    3, 3,
    sharex=True,
    sharey=True,
    constrained_layout=True,
    figsize=[20, 20]
)

axes_flat = axes.ravel()
all_ax = axes_flat[-1]

# -------------------------------------------
# LOOP OVER REGIONS (1–8)
# -------------------------------------------
for i, ax in enumerate(axes_flat[:-1]):

    # Cumulative signals
    diff_cumsum = np.cumsum(df['volcano'] - df[f'clear_{i+1}'])
    volc_cumsum = np.cumsum(df['volcano'])
    clear_cumsum = np.cumsum(df[f'clear_{i+1}'])

    # ---- ALL REGIONS PANEL (colour-coded) ----
    all_ax.plot(
        df['date'],
        diff_cumsum,
        color=f'C{i}',
        alpha=0.8,
        label=f'Clear Zone {i+1}'
    )

    # ---- INDIVIDUAL REGION PANEL ----
    ax.plot(
        df['date'],
        diff_cumsum,
        'k-', label='Difference'
    )

    ax.plot(
        df['date'],
        volc_cumsum,
        'C1-', alpha=0.5, label='Volcano'
    )

    ax.plot(
        df['date'],
        clear_cumsum,
        'C2-', alpha=0.5, label='Clear'
    )

    ax.set_title(f'Clear Zone {i+1}')

    if i == 0:
        ax.legend()

    if i in [0, 3, 6]:
        ax.set_ylabel('Cumulative SO$_2$ [a.u.]')

# -------------------------------------------
# ALL REGIONS PANEL FORMATTING
# -------------------------------------------
all_ax.set_title('All Clear Zones')
all_ax.legend(
    loc='upper left',
    ncol=2,
    frameon=False
)

locator = mdates.AutoDateLocator()
formatter = mdates.ConciseDateFormatter(locator)
all_ax.xaxis.set_major_locator(locator)
all_ax.xaxis.set_major_formatter(formatter)

plt.show()

# %%
# Plot the clear-corrected and detrended data

fig, ax = plt.subplots(figsize=[7, 4])

for i in range(len(config['clear_locations'])):
    signal = np.cumsum(df['volcano'] - df[f'clear_{i+1}'])
    detrended_signal = np.subtract(
        signal,
        np.polyval(
            [signal.to_numpy()[-1]/len(df['date']), 0],
            np.arange(len(df['date'])))
    )
    ax.plot(
        df['date'],
        detrended_signal,
        f'C{i}-',
        alpha=0.5,
        label=f'Clear {i+1}'
    )

ax.legend(loc='upper left', ncol=2)

locator = mdates.AutoDateLocator()
formatter = mdates.ConciseDateFormatter(locator)
ax.xaxis.set_major_locator(locator)
ax.xaxis.set_major_formatter(formatter)

ax.set_ylabel('Detrended SO$_2$ Signal (a.u.)')

plt.savefig("figure2.png", dpi=800, bbox_inches='tight')
plt.show()
